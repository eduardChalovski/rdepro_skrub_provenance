# %%
import skrub
import pandas as pd
from monkey_patching_v0 import provenance_func_name

def set_provenance(namespace, name_of_the_function, provenance_func=provenance_func_name):
    skrub_eval_namespace = namespace
    name = name_of_the_function
    skrub_eval = getattr(skrub_eval_namespace,name,None)
    setattr(skrub_eval_namespace, name, provenance_func(skrub_eval))
    print(f"Set provenance for {name}")

set_provenance(skrub._data_ops._data_ops.DataOp, "__call__")
# Out:
# Set provenance for __call__

# %%
df1 = pd.DataFrame({"Country": ["USA", "Italy", "Georgia"]})#.astype("string").set_index("Country")
df2 = pd.DataFrame({"Country": ["Spain", "Belgium", "Italy"],
                    "Capital": ["Madrid", "Brussel", "Rome"]})#.astype("string").set_index("Country")

main_table = skrub.var("main_table", df1)
aux_table = skrub.var("aux_table", df2)

joined = (
    main_table
    #.assign(Country=main_table["Country"].astype("string"))
    .merge(
        aux_table,
        #.assign(Country=aux_table["Country"].astype("string"))
        #.set_index("Country"),
        on="Country",
        how="left",
    )
)
joined
# Out:
# [PROVENANCE]: START
# I know you executed __call__
# now I will tell you the args
#
# argument 0:  <GetAttr 'merge'>
# Result:
# ―――――――
# <bound method DataFrame.merge of    Country
# 0      USA
# 1    Italy
# 2  Georgia>
# type(argument):  <class 'skrub._data_ops._data_ops.DataOp'>
#
# argument 1:  <Var 'aux_table'>
# Result:
# ―――――――
#    Country  Capital
# 0    Spain   Madrid
# 1  Belgium  Brussel
# 2    Italy     Rome
# type(argument):  <class 'skrub._data_ops._data_ops.DataOp'>
# -----------------------------------
# now I will go over keyword arguments
# the keyword is: >>> on <<< the value will be printed below:
# Country
# the keyword is: >>> how <<< the value will be printed below:
# left
# [PROVENANCE]: END
# <CallMethod 'merge'>
# Result:
# ―――――――
#    Country Capital
# 0      USA     NaN
# 1    Italy    Rome
# 2  Georgia     NaN

# %%
df3 = pd.DataFrame({"Name": ["Person1", "Person2", "Person3"],
                    "Home Country": ["Italy", "Italy", "Germany"]})#.set_index("Country")
people_table = skrub.var("people_table", df3)

joined2 = (
    joined
    #.assign(Country=main_table["Country"].astype("string"))
    .merge(
        people_table,
        #.assign(Country=people_table["Home Country"].astype("string"))
        #.set_index("Country"),
        left_on="Country", right_on="Home Country",
        how="left",
    )
)
joined2
# Out:
# [PROVENANCE]: START
# I know you executed __call__
# now I will tell you the args
#
# argument 0:  <GetAttr 'merge'>
# Result:
# ―――――――
# <bound method DataFrame.merge of    Country Capital
# 0      USA     NaN
# 1    Italy    Rome
# 2  Georgia     NaN>
# type(argument):  <class 'skrub._data_ops._data_ops.DataOp'>
#
# argument 1:  <Var 'people_table'>
# Result:
# ―――――――
#       Name Home Country
# 0  Person1        Italy
# 1  Person2        Italy
# 2  Person3      Germany
# type(argument):  <class 'skrub._data_ops._data_ops.DataOp'>
# -----------------------------------
# now I will go over keyword arguments
# the keyword is: >>> left_on <<< the value will be printed below:
# Country
# the keyword is: >>> right_on <<< the value will be printed below:
# Home Country
# the keyword is: >>> how <<< the value will be printed below:
# left
# [PROVENANCE]: END
# <CallMethod 'merge'>
# Result:
# ―――――――
#    Country Capital     Name Home Country
# 0      USA     NaN      NaN          NaN
# 1    Italy    Rome  Person1        Italy
# 2    Italy    Rome  Person2        Italy
# 3  Georgia     NaN      NaN          NaN

# %%
# Aggregation
aggregation_df = joined2.groupby("Capital").agg([list,"count"])
aggregation_df
# Out:
# [PROVENANCE]: START
# I know you executed __call__
# now I will tell you the args
#
# argument 0:  <GetAttr 'groupby'>
# Result:
# ―――――――
# <bound method DataFrame.groupby of    Country Capital     Name Home Country
# 0      USA     NaN      NaN          NaN
# 1    Italy    Rome  Person1        Italy
# 2    Italy    Rome  Person2        Italy
# 3  Georgia     NaN      NaN          NaN>
# type(argument):  <class 'skrub._data_ops._data_ops.DataOp'>
# argument 1:  Capital
# type(argument):  <class 'str'>
# -----------------------------------
# There are no kwargs.
# [PROVENANCE]: END
# [PROVENANCE]: START
# I know you executed __call__
# now I will tell you the args
#
# argument 0:  <GetAttr 'agg'>
# Result:
# ―――――――
# <bound method DataFrameGroupBy.aggregate of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000020B5A58FFB0>>
# type(argument):  <class 'skrub._data_ops._data_ops.DataOp'>
# -----------------------------------
# check on the type of argument class list is successful
# now iterating over each element of the list:
# that is the 0th element
# <class 'list'>
# that is the 1th element
# count
# -----------------------------------
# There are no kwargs.
# [PROVENANCE]: END
# <CallMethod 'agg'>
# Result:
# ―――――――
#                 Country                      Name          Home Country
#                    list count                list count            list count
# Capital
# Rome     [Italy, Italy]     2  [Person1, Person2]     2  [Italy, Italy]     2

# %%
# Selection
aggregation_selection_df = aggregation_df[["Name","Home Country"]]
aggregation_selection_df
# Out:
# <GetItem ['Name', 'Home Country']>
# Result:
# ―――――――
#                        Name          Home Country
#                        list count            list count
# Capital
# Rome     [Person1, Person2]     2  [Italy, Italy]     2

# %%
# Projection
result_df = aggregation_selection_df.assign(Country=aggregation_selection_df[("Home Country","list")])
result_df
# Out:
# [PROVENANCE]: START
# I know you executed __call__
# now I will tell you the args
#
# argument 0:  <GetAttr 'assign'>
# Result:
# ―――――――
# <bound method DataFrame.assign of                        Name          Home Country
#                        list count            list count
# Capital
# Rome     [Person1, Person2]     2  [Italy, Italy]     2>
# type(argument):  <class 'skrub._data_ops._data_ops.DataOp'>
# -----------------------------------
# now I will go over keyword arguments
# the keyword is: >>> Country <<< the value will be printed below:
# <GetItem ('Home Country', 'list')>
# Result:
# ―――――――
# Capital
# Rome    [Italy, Italy]
# Name: (Home Country, list), dtype: object
# [PROVENANCE]: END
# <CallMethod 'assign'>
# Result:
# ―――――――
#                        Name          Home Country               Country
#                        list count            list count
# Capital
# Rome     [Person1, Person2]     2  [Italy, Italy]     2  [Italy, Italy]

# %% [markdown]
# ### Let's execute the same pipeline but each ASPJ operator is marked by a decorator function now.
#
# #### For each passed function name in name_of_original_functions a provenance function is passed to wrap_skrub()
# #### For now they are all provenance_func_name() (it prints the function name) but they can be customized: pd.merge will get assigned provenance_of_merge(), and df[] will get assigned provenance_select()

# %%
from monkey_patching_v0 import wrap_skrub, provenance_func_name

# %%
import pandas as pd
import skrub


df1 = pd.DataFrame({"Country": ["USA", "Italy", "Georgia"]})#.astype("string").set_index("Country")
df2 = pd.DataFrame({"Country": ["Spain", "Belgium", "Italy"],
                    "Capital": ["Madrid", "Brussel", "Rome"]})#.astype("string").set_index("Country")

name_of_original_functions = ["df[]", "df.merge", "groupby", "agg", "assign"]
length_of_original_names = len(name_of_original_functions)
skrub.var = wrap_skrub(skrub.var, 
                       names_of_original_functions=name_of_original_functions, 
                       provenance_wrapper_for_the_function=[provenance_func_name]*length_of_original_names)

main_table = skrub.var("main_table", df1)
aux_table = skrub.var("aux_table", df2)

joined = (
    main_table
    .merge(
        aux_table,
        on="Country",
        how="left",
    )
)
joined
# Out:
# I know you executed merge
# now I will tell you the args
# argument:     Country
# 0      USA
# 1    Italy
# 2  Georgia
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:     Country  Capital
# 0    Spain   Madrid
# 1  Belgium  Brussel
# 2    Italy     Rome
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# -----------------------------------
# now I will go over keyword arguments
# the keyword is:  on  the value will be printed below:
# Country
# the keyword is:  how  the value will be printed below:
# left
# I know you executed __getitem__
# now I will tell you the args
# argument:     Country  Capital
# 0    Spain   Madrid
# 1  Belgium  Brussel
# 2    Italy     Rome
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  Country
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:     Country
# 0      USA
# 1    Italy
# 2  Georgia
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  Country
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:     Country
# 0      USA
# 1    Italy
# 2  Georgia
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  slice(None, None, None)
# type(argument):  <class 'slice'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:     Capital
# 0   Madrid
# 1  Brussel
# 2     Rome
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  slice(None, None, None)
# type(argument):  <class 'slice'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:       value  count
# 0      USA      1
# 1    Italy      1
# 2  Georgia      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:    value  count
# 0  Rome      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# <CallMethod 'merge'>
# Result:
# ―――――――
#    Country Capital
# 0      USA     NaN
# 1    Italy    Rome
# 2  Georgia     NaN

# %% [markdown]
# #### By introducing provenance for \_\_getitem\_\_ -> we can see that it is being called inside the merge function. Find the most basic operators like \_\_getitem\_\_ and implement provenance for them

# %%
df3 = pd.DataFrame({"Name": ["Person1", "Person2", "Person3"],
                             "Home Country": ["Italy", "Italy", "Germany"]})#.set_index("Country")
people_table = skrub.var("people_table", df3)

joined2 = (
    joined
    .merge(
        people_table,
        left_on="Country", right_on="Home Country",
        how="left",
    )
)
joined2
# Out:
# I know you executed merge
# now I will tell you the args
# argument:     Country Capital
# 0      USA     NaN
# 1    Italy    Rome
# 2  Georgia     NaN
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:        Name Home Country
# 0  Person1        Italy
# 1  Person2        Italy
# 2  Person3      Germany
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# -----------------------------------
# now I will go over keyword arguments
# the keyword is:  left_on  the value will be printed below:
# Country
# the keyword is:  right_on  the value will be printed below:
# Home Country
# the keyword is:  how  the value will be printed below:
# left
# I know you executed __getitem__
# now I will tell you the args
# argument:        Name Home Country
# 0  Person1        Italy
# 1  Person2        Italy
# 2  Person3      Germany
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  Home Country
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:     Country Capital
# 0      USA     NaN
# 1    Italy    Rome
# 2  Georgia     NaN
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  Country
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:     Country Capital
# 0      USA     NaN
# 1    Italy    Rome
# 2  Georgia     NaN
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  slice(None, None, None)
# type(argument):  <class 'slice'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:        Name Home Country
# 0  Person1        Italy
# 1  Person2        Italy
# 2  Person3      Germany
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  slice(None, None, None)
# type(argument):  <class 'slice'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:       value  count
# 0    Italy      2
# 1      USA      1
# 2  Georgia      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:    value  count
# 0  Rome      2
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:       value  count
# 0  Person1      1
# 1  Person2      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:     value  count
# 0  Italy      2
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# <CallMethod 'merge'>
# Result:
# ―――――――
#    Country Capital     Name Home Country
# 0      USA     NaN      NaN          NaN
# 1    Italy    Rome  Person1        Italy
# 2    Italy    Rome  Person2        Italy
# 3  Georgia     NaN      NaN          NaN

# %% [markdown]
# #### Interesting that func.\_\_name\_\_ for groupby() is not "groupby" -> I do not find any name for groupby

# %%
# Aggregation
aggregation_df = joined2.groupby("Capital").agg([list,"count"])
aggregation_df
# Out:
# I know you executed __getitem__
# now I will tell you the args
# argument:     Country Capital     Name Home Country
# 0      USA     NaN      NaN          NaN
# 1    Italy    Rome  Person1        Italy
# 2    Italy    Rome  Person2        Italy
# 3  Georgia     NaN      NaN          NaN
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  Capital
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed aggregate
# now I will tell you the args
# argument:  <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000195BAF2AB10>
# type(argument):  <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# -----------------------------------
# check on the type of argument class list is successful
# now iterating over each element of the list:
# that is the 0th element
# <class 'list'>
# that is the 1th element
# count
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:              value  count
# 0  [Italy, Italy]      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:                  value  count
# 0  [Person1, Person2]      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:              value  count
# 0  [Italy, Italy]      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# <CallMethod 'agg'>
# Result:
# ―――――――
#                 Country                      Name          Home Country
#                    list count                list count            list count
# Capital
# Rome     [Italy, Italy]     2  [Person1, Person2]     2  [Italy, Italy]     2

# %%
# Selection
aggregation_selection_df = aggregation_df[["Name","Home Country"]]
aggregation_selection_df
# Out:
# I know you executed __getitem__
# now I will tell you the args
# argument:                  Country                      Name          Home Country
#                    list count                list count            list count
# Capital
# Rome     [Italy, Italy]     2  [Person1, Person2]     2  [Italy, Italy]     2
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# -----------------------------------
# check on the type of argument class list is successful
# now iterating over each element of the list:
# that is the 0th element
# Name
# that is the 1th element
# Home Country
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:                  value  count
# 0  [Person1, Person2]      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:              value  count
# 0  [Italy, Italy]      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# <GetItem ['Name', 'Home Country']>
# Result:
# ―――――――
#                        Name          Home Country
#                        list count            list count
# Capital
# Rome     [Person1, Person2]     2  [Italy, Italy]     2

# %%
# Projection
result_df = aggregation_selection_df.assign(Country=aggregation_selection_df[("Home Country","list")])
result_df
# Out:
# I know you executed __getitem__
# now I will tell you the args
# argument:                         Name          Home Country
#                        list count            list count
# Capital
# Rome     [Person1, Person2]     2  [Italy, Italy]     2
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  ('Home Country', 'list')
# type(argument):  <class 'tuple'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed assign
# now I will tell you the args
# argument:                         Name          Home Country
#                        list count            list count
# Capital
# Rome     [Person1, Person2]     2  [Italy, Italy]     2
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# -----------------------------------
# now I will go over keyword arguments
# the key is:  Country  the value is:
# Capital
# Rome    [Italy, Italy]
# Name: (Home Country, list), dtype: object
# I know you executed __getitem__
# now I will tell you the args
# argument:                  value  count
# 0  [Person1, Person2]      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:              value  count
# 0  [Italy, Italy]      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# I know you executed __getitem__
# now I will tell you the args
# argument:              value  count
# 0  [Italy, Italy]      1
# type(argument):  <class 'pandas.core.frame.DataFrame'>
# argument:  count
# type(argument):  <class 'str'>
# -----------------------------------
# now I will go over keyword arguments
# <CallMethod 'assign'>
# Result:
# ―――――――
#                        Name          Home Country               Country
#                        list count            list count
# Capital
# Rome     [Person1, Person2]     2  [Italy, Italy]     2  [Italy, Italy]

# %%
#import pandas as pd
#from skrub import Joiner
#df1 = pd.DataFrame({"Country": ["USA", "Italia", "Georgia"]})
#df2 = pd.DataFrame( {"Country": ["Spain", "Belgium", "Italy"],
#                           "Capital": ["Madrid", "Brussel", "Rome"]} )
#df3 = pd.DataFrame({"Name": ["Person1", "Person2", "Person3"],
#                             "Home Country": ["Italy", "Italia", "Germany"]})
#
#main_table = skrub.var("main_table", df1)
#aux_table = skrub.var("aux_table", df2)
#people_table = skrub.var("people_table", df3)
#
#
##main_table_fixed = main_table.astype({"Country": "string"})
##aux_table_fixed = aux_table.astype({"Country": "string"})
#
#
##joined1 = (
##    main_table[["Country"]].astype({"Country": "string"}).join(
##        aux_table[["Country", "Capital"]].astype({"Country": "string"}),
##        on="Country",
##        how="left",
##    )
##)
#
#
## Joiner executes a fuzzy join. I did not find a way to make this skrub function work with DataOps
#joiner = Joiner(
#    df2,
#    key="Country",
#    suffix="_aux",
#    max_dist=0.8,
#    add_match_info=False,
#)
#main_table.skb.apply(joiner.fit_transform)
#main_and_aux_table = joiner.fit_transform(df1)
#main_and_aux_table
# Out:
#    Country Country_aux Capital_aux
# 0      USA         NaN         NaN
# 1   Italia       Italy        Rome
# 2  Georgia         NaN         NaN

# %%
# Joiner executes a fuzzy join. I did not find a way to make this skrub function work with DataOps
#joiner = Joiner(
#    aux_table,
#    key="Country",
#    suffix="_aux",
#    max_dist=0.8,
#    add_match_info=False,
#)
#main_table.skb.apply_func(joiner.fit_transform)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_data_ops.py:341, in check_data_op.<locals>.checked_call(*args, **kwargs)
#
#     340 try:
#
# --> 341     evaluate(data_op, mode="preview", environment=None)
#
#     342 except UninitializedVariable:
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_evaluation.py:447, in evaluate(data_op, mode, environment, clear, callbacks)
#
#     446 try:
#
# --> 447     return _Evaluator(mode=mode, environment=environment, callbacks=callbacks).run(
#
#     448         data_op
#
#     449     )
#
#     450 finally:
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_evaluation.py:283, in _Evaluator.run(self, data_op)
#
#     282 self._data_op = data_op
#
# --> 283 return super().run(data_op)
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_evaluation.py:177, in _DataOpTraversal.run(self, data_op)
#
#     176 if isinstance(top, _Computation):
#
# --> 177     step()
#
#     178 elif isinstance(top, _CurrentNodeDuration):
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_evaluation.py:159, in _DataOpTraversal.run.<locals>.step()
#
#     158 try:
#
# --> 159     new_top = top.generator.send(last_result)
#
#     160 finally:
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_evaluation.py:317, in _Evaluator.handle_data_op(self, data_op)
#
#     316     pass
#
# --> 317 result = yield from self._eval_data_op(data_op)
#
#     318 duration = yield _CurrentNodeDuration()
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_evaluation.py:331, in _Evaluator._eval_data_op(self, data_op)
#
#     328         return (
#
#     329             yield from impl.eval(mode=self.mode, environment=self.environment)
#
#     330         )
#
# --> 331     return (yield from super().handle_data_op(data_op))
#
#     332 except Exception as e:
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_evaluation.py:211, in _DataOpTraversal.handle_data_op(self, data_op)
#
#     210     evaluated_attributes[name] = yield attr
#
# --> 211 return self.compute_result(data_op, evaluated_attributes)
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_evaluation.py:361, in _Evaluator.compute_result(self, data_op, evaluated_attributes)
#
#     360 def compute_result(self, data_op, evaluated_attributes):
#
# --> 361     return data_op._skrub_impl.compute(
#
#     362         SimpleNamespace(**evaluated_attributes),
#
#     363         mode=self.mode,
#
#     364         environment=self.environment,
#
#     365     )
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_data_ops.py:1461, in Call.compute(self, e, mode, environment)
#
#    1460 kwargs = (e.kwdefaults or {}) | e.kwargs
#
# -> 1461 return func(*e.args, **kwargs)
#
#
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#
#     311 @wraps(f)
#
#     312 def wrapped(self, X, *args, **kwargs):
#
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#
#     314     if isinstance(data_to_wrap, tuple):
#
#     315         # only wrap the first output for cross decomposition
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_joiner.py:300, in Joiner.fit_transform(self, X, y)
#
#     286 """Fit the instance to the main table.
#
#     287
#
#     288 Parameters
#
#    (...)
#
#     298     The final joined table.
#
#     299 """
#
# --> 300 self._aux_table = CheckInputDataFrame().fit_transform(self.aux_table)
#
#     301 self._main_check_input = CheckInputDataFrame()
#
#
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#
#     311 @wraps(f)
#
#     312 def wrapped(self, X, *args, **kwargs):
#
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#
#     314     if isinstance(data_to_wrap, tuple):
#
#     315         # only wrap the first output for cross decomposition
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_check_input.py:125, in CheckInputDataFrame.fit_transform(***failed resolving arguments***)
#
#     124 X = self._handle_array(X)
#
# --> 125 _check_is_dataframe(X)
#
#     126 self.module_name_ = sbd.dataframe_module_name(X)
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_check_input.py:68, in _check_is_dataframe(df)
#
#      67 if not sbd.is_dataframe(df):
#
# ---> 68     raise TypeError(
#
#      69         "Only pandas and polars DataFrames are supported. Cannot handle X of"
#
#      70         f" type: {type(df)}."
#
#      71     )
#
#
#
# TypeError: Only pandas and polars DataFrames are supported. Cannot handle X of type: <class 'skrub._data_ops._data_ops.DataOp'>.
#
#
#
# The above exception was the direct cause of the following exception:
#
#
#
# RuntimeError                              Traceback (most recent call last)
#
# Cell In[125], line 9
#
#       1 # Joiner executes a fuzzy join. I did not find a way to make this skrub function work with DataOps
#
#       2 joiner = Joiner(
#
#       3     aux_table,
#
#       4     key="Country",
#
#    (...)
#
#       7     add_match_info=False,
#
#       8 )
#
# ----> 9 main_table.skb.apply_func(joiner.fit_transform)
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_skrub_namespace.py:396, in SkrubNamespace.apply_func(self, func, *args, **kwargs)
#
#     334 def apply_func(self, func, *args, **kwargs):
#
#     335     r"""Apply the given function.
#
#     336
#
#     337     This is a convenience function; ``X.skb.apply_func(func)`` is
#
#    (...)
#
#     394     2
#
#     395     """
#
# --> 396     return deferred(func)(self._data_op, *args, **kwargs)
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_data_ops.py:381, in _check_return_value.<locals>.check_call_return_value(*args, **kwargs)
#
#     379 @functools.wraps(f)
#
#     380 def check_call_return_value(*args, **kwargs):
#
# --> 381     data_op = f(*args, **kwargs)
#
#     382     if "preview" not in data_op._skrub_impl.results:
#
#     383         return data_op
#
#
#
# File ~\anaconda3\Lib\site-packages\skrub\_data_ops\_data_ops.py:346, in check_data_op.<locals>.checked_call(*args, **kwargs)
#
#     344 except Exception as e:
#
#     345     msg = "\n".join(_utils.format_exception_only(e)).rstrip("\n")
#
# --> 346     raise RuntimeError(
#
#     347         f"Evaluation of {func_name!r} failed.\n"
#
#     348         f"You can see the full traceback above. The error message was:\n{msg}"
#
#     349     ) from e
#
#     351 return data_op
#
#
#
# RuntimeError: Evaluation of 'fit_transform()' failed.
#
# You can see the full traceback above. The error message was:
#
# TypeError: Only pandas and polars DataFrames are supported. Cannot handle X of type: <class 'skrub._data_ops._data_ops.DataOp'>.

# %%
#joiner_all = Joiner(
#    main_and_aux_table,
#    main_key="Home Country",
#    aux_key="Country",
#    suffix="_aux",
#    max_dist=0.8,
#    add_match_info=False,
##)
#main_and_people_and_aux_table = joiner_all.fit_transform(peopele_and_aux_table)
#main_and_people_and_aux_table
# Out:
#       Name Home Country Country_aux Capital_aux Country_aux__skrub_d0c22b71__  \
# 0  Person1        Italy       Italy        Rome                        Italia
# 1  Person2       Italia       Italy        Rome                        Italia
# 2  Person3      Germany     Germany      Berlin                           NaN
#
#   Country_aux_aux Capital_aux_aux
# 0           Italy            Rome
# 1           Italy            Rome
# 2             NaN             NaN

# %%
#joiner = Joiner(
#    aux_table,
#    main_key="Home Country",
#    aux_key="Country",
#    suffix="_aux",
#    max_dist=0.8,
#    add_match_info=False,
#)
#joiner.fit_transform(people_table)
# Out:
#       Name Home Country Country_aux Capital_aux
# 0  Person1        Italy       Italy        Rome
# 1  Person2       Italia       Italy        Rome
# 2  Person3      Germany         NaN         NaN

# %%
import duckdb
@deffered
def project_with_duckdb(a_dataframe, which_column, new_name):
    cursor = duckdb.connect()
    query = f""" SELECT "{which_column}" AS "{new_name}" from a_dataframe """
    return cursor.execute(query).fetch_df()
