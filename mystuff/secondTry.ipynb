# %%
import pandas as pd
from importlib import reload
import skrub
from functools import wraps
from skrub import selectors as s
import importlib.util
import sys
from pathlib import Path

# %%
#import monkey patch so we can disable and enable easily
module_path = Path("C:/Users/teodo/Desktop/github/rdepro_skrub_provenance/mystuff/SkrubMonkeyPatch.py")  #i am stupid and couldnt make 
spec = importlib.util.spec_from_file_location("mymodule2", str(module_path))                        #the import run in a different way :3
monkeyPatch = importlib.util.module_from_spec(spec)
sys.modules["mymodule2"] = monkeyPatch
spec.loader.exec_module(monkeyPatch)

dir(monkeyPatch)
# Out:
# ['PROV_COLUMN',
#  'Path',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'importlib',
#  'pd',
#  'reload',
#  's',
#  'skrub',
#  'sys',
#  'varProvenanceAdder',
#  'wraps']

# %%
df1 = pd.DataFrame({
    "id": [1, 2, 3],
    "name": ["Alice", "Bob", "Charlie"]
    
})
df2 = pd.DataFrame ({
    "id": [1, 2, 4],
    "age": [24, 30, 50]
})
display(df1)
display(df2)
# Out:
#    id     name   _prov
# 0   1    Alice  prov_0
# 1   2      Bob  prov_1
# 2   3  Charlie  prov_2
#    id  age   _prov
# 0   1   24  prov_0
# 1   2   30  prov_1
# 2   4   50  prov_2

# %%
my_df1 = skrub.var("my_df1",df1)
my_df2 = skrub.var("my_df2",df2)
my_df1.merge(my_df2, on="id")
# Out:
# <CallMethod 'merge'>
# Result:
# ―――――――
#    id   name _prov_x  age _prov_y
# 0   1  Alice  prov_0   24  prov_0
# 1   2    Bob  prov_1   30  prov_1
